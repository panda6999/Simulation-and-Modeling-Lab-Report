# %% [markdown]
# <a href="https://colab.research.google.com/github/panda6999/Simulation-and-Modeling-Lab-Report/blob/main/Home_task05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# MD. HABIBUL BASHAR
#
# ID: 2215151046
#
# Section: 7(A2)
#
# Course: Simulation and Modeling Lab
#
# Course Code: CSE 413
#
# Home Task: 05

# %%
import numpy as np
from scipy.stats import kstest, norm
import matplotlib.pyplot as plt

# %%
#Dataset: Daily tempuratures over a 10-day period
temperatures = [15, 17, 16, 14, 18, 20, 19, 15, 21, 22]

# Define mean and standard deviation for the normal distribution
mu = np.mean(temperatures)
sigma = np.std(temperatures)

#Center and scale the data (standardize)
z = (np.array(temperatures) - mu) / sigma

# perform one-sample kolmogorov-smirov test againts standard normal distribution

h, p = kstest(z, 'norm')
ksstat = kstest(z, 'norm')[0]

#output the results
print(f'Test decision (h):{h}')
print(f'p-value:{p:4f}')
print(f'KS statistic: {ksstat:.4f}')

#plot Empirical CDF vs standard normal Cdf
plt.figure()
plt.hist(y, cumulative=True, density=True, label='Empirical CDF')
x = np.linspace(min(z), max(z), 100)
plt.plot(x, norm.cdf(x, 0, 1), 'r--', linewidth=2, label='Standard Normal CDF')
plt.legend()
plt.title('Empirical CDF vs Standard Normal CDF')
plt.xlabel('Standard Teeperature')
plt.ylabel('Cumulative probability')
plt.grid(True)
plt.show()
# Out:
# Test decision (h):0.14958199200873884
# p-value:0.954973
# KS statistic: 0.1496
